# %%
from requests import Request, Session
from requests.exceptions import ConnectionError, Timeout, TooManyRedirects
import json

url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
#Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
parameters = {
  'start':'1',
  'limit':'15',
  'convert':'USD'
}
headers = {
  'Accepts': 'application/json',
  'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
}

session = Session()
session.headers.update(headers)

try:
  response = session.get(url, params=parameters)
  data = json.loads(response.text)
  #print(data)
except (ConnectionError, Timeout, TooManyRedirects) as e:
  print(e)

#NOTE:
# I had to go in and put "jupyter notebook --NotebookApp.iopub_data_rate_limit=1e10"
# Into the Anaconda Prompt to change this to allow to pull data

# If that didn't work try using the local host URL as shown in the video

# %%
type(data)

# %%
import pandas as pd


#This allows you to see all the columns, not just like 15
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
#This normalizes the data and makes it all pretty in a dataframe

df = pd.json_normalize(data['data'])
df['timestamp'] = pd.to_datetime('now')
df

# %%
def api_runner():
    global df
    url = 'https://pro-api.coinmarketcap.com/v1/cryptocurrency/listings/latest' 
    #Original Sandbox Environment: 'https://sandbox-api.coinmarketcap.com/v1/cryptocurrency/listings/latest'
    parameters = {
      'start':'1',
      'limit':'15',
      'convert':'USD'
    }
    headers = {
      'Accepts': 'application/json',
      'X-CMC_PRO_API_KEY': '0ad53085-1cb2-4eb8-ad9e-3ffbd7e56509',
    }

    session = Session()
    session.headers.update(headers)

    try:
      response = session.get(url, params=parameters)
      data = json.loads(response.text)
  #print(data)
    except (ConnectionError, Timeout, TooManyRedirects) as e:
      print(e)


    df2 = pd.json_normalize(data['data'])
    df2['timestamp'] = pd.to_datetime('now')
    
                                       # df = df2.append(df2)
                                       #df_append = pd.DataFrame(df2)
                                       #df = pd.concat([df2,df_append])
    df_append = pd.DataFrame(df2)
    df = pd.concat([df,df_append])
    
# Used for writing to a csv instead of a dataframe
    
    #if not os.path.isfile(r'C:\Users\bloop\Desktop\excel portfolio\API\API.csv'):
       # df.to_csv(r'C:\Users\bloop\Desktop\excel portfolio\API\API.csv', header = 'column_names')
    #else:
        #df.to_csv(r'C:\Users\bloop\Desktop\excel portfolio\API\API.csv', mode= 'a', header = False)

# %%
import os
from time import time
from time import sleep

for i in range(333):
    api_runner()
    print('API Runner Completed successfully')
    sleep(10) #sleeps for 1 minute
exit()
# Out:
# API Runner Completed successfully
# API Runner Completed successfully
# API Runner Completed successfully
# API Runner Completed successfully
# API Runner Completed successfully
# API Runner Completed successfully
# API Runner Completed successfully
# API Runner Completed successfully
# API Runner Completed successfully
# API Runner Completed successfully
# API Runner Completed successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 8
#       6     api_runner()
#       7     print('API Runner Completed successfully')
# ----> 8     sleep(10) #sleeps for 1 minute
#       9 exit()
#
# KeyboardInterrupt:

# %%
#Reading data from created CSV file

#dfcsv = pd.read_csv(r'C:\Users\bloop\Desktop\excel portfolio\API\API.csv')
#dfcsv
# Out:
#      Unnamed: 0     id         name symbol          slug  num_market_pairs  \
# 0             0      1      Bitcoin    BTC       bitcoin             10866
# 1             1   1027     Ethereum    ETH      ethereum              8531
# 2             2    825  Tether USDt   USDT        tether             77849
# 3             3   1839          BNB    BNB           bnb              2091
# 4             4   5426       Solana    SOL        solana               636
# 5             5     52          XRP    XRP           xrp              1247
# 6             6   3408         USDC   USDC      usd-coin             17176
# 7             7   2010      Cardano    ADA       cardano              1096
# 8             8     74     Dogecoin   DOGE      dogecoin               916
# 9             9   5805    Avalanche   AVAX     avalanche               678
# 10           10   5994    Shiba Inu   SHIB     shiba-inu               762
# ...

# %%
pd.set_option('display.float_format', lambda x:'%.5f' %x)

# %%
df

# %%
df3 = df.groupby('name', sort=False)[['quote.USD.percent_change_1h','quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d']].mean()

df3
# Out:
#              quote.USD.percent_change_1h  quote.USD.percent_change_24h  \
# name
# Bitcoin                         -0.38674                      -0.99238
# Ethereum                        -0.42202                      -1.25543
# Tether USDt                     -0.00252                      -0.08647
# BNB                              0.09567                       5.05390
# Solana                           0.46795                       1.73537
# XRP                              0.19899                       1.29368
# USDC                            -0.00253                      -0.00488
# Cardano                          0.35578                      -1.46617
# Dogecoin                         0.07265                      -2.84791
# Avalanche                        6.19057                      14.75780
# Shiba Inu                        0.04909                      -1.47419
# Polkadot                        -0.06427                      -1.90665
# ...

# %%
df4 = df3.stack()
df4
# Out:
# name
# Bitcoin      quote.USD.percent_change_1h     -0.38674
#              quote.USD.percent_change_24h    -0.99238
#              quote.USD.percent_change_7d      8.28674
#              quote.USD.percent_change_30d    48.62169
#              quote.USD.percent_change_60d    61.43149
#              quote.USD.percent_change_90d    70.33648
# Ethereum     quote.USD.percent_change_1h     -0.42202
#              quote.USD.percent_change_24h    -1.25543
#              quote.USD.percent_change_7d      6.24050
#              quote.USD.percent_change_30d    58.42147
#              quote.USD.percent_change_60d    49.64697
#              quote.USD.percent_change_90d    79.05833
# Tether USDt  quote.USD.percent_change_1h     -0.00252
#              quote.USD.percent_change_24h    -0.08647
#              quote.USD.percent_change_7d     -0.01904
#              quote.USD.percent_change_30d    -0.03445
#              quote.USD.percent_change_60d     0.04027
# ...

# %%
type(df4)
# Out:
# pandas.core.series.Series

# %%
df5 = df4.to_frame(name = 'values')
df5
# Out:
#                                             values
# name
# Bitcoin     quote.USD.percent_change_1h   -0.38674
#             quote.USD.percent_change_24h  -0.99238
#             quote.USD.percent_change_7d    8.28674
#             quote.USD.percent_change_30d  48.62169
#             quote.USD.percent_change_60d  61.43149
#             quote.USD.percent_change_90d  70.33648
# Ethereum    quote.USD.percent_change_1h   -0.42202
#             quote.USD.percent_change_24h  -1.25543
#             quote.USD.percent_change_7d    6.24050
#             quote.USD.percent_change_30d  58.42147
#             quote.USD.percent_change_60d  49.64697
#             quote.USD.percent_change_90d  79.05833
# Tether USDt quote.USD.percent_change_1h   -0.00252
#             quote.USD.percent_change_24h  -0.08647
#             quote.USD.percent_change_7d   -0.01904
#             quote.USD.percent_change_30d  -0.03445
#             quote.USD.percent_change_60d   0.04027
# ...

# %%
df5.count()
# Out:
# values    90
# dtype: int64

# %%
index = pd.Index(range(90))

df6 = df5.reset_index()
df6
# Out:
#            name                       level_1    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.38674
# 1       Bitcoin  quote.USD.percent_change_24h  -0.99238
# 2       Bitcoin   quote.USD.percent_change_7d   8.28674
# 3       Bitcoin  quote.USD.percent_change_30d  48.62169
# 4       Bitcoin  quote.USD.percent_change_60d  61.43149
# 5       Bitcoin  quote.USD.percent_change_90d  70.33648
# 6      Ethereum   quote.USD.percent_change_1h  -0.42202
# 7      Ethereum  quote.USD.percent_change_24h  -1.25543
# 8      Ethereum   quote.USD.percent_change_7d   6.24050
# 9      Ethereum  quote.USD.percent_change_30d  58.42147
# 10     Ethereum  quote.USD.percent_change_60d  49.64697
# 11     Ethereum  quote.USD.percent_change_90d  79.05833
# 12  Tether USDt   quote.USD.percent_change_1h  -0.00252
# 13  Tether USDt  quote.USD.percent_change_24h  -0.08647
# 14  Tether USDt   quote.USD.percent_change_7d  -0.01904
# 15  Tether USDt  quote.USD.percent_change_30d  -0.03445
# ...

# %%
df7 = df6.rename(columns = {'level_1':'percent_change'})
df7
# Out:
#            name                percent_change    values
# 0       Bitcoin   quote.USD.percent_change_1h  -0.38674
# 1       Bitcoin  quote.USD.percent_change_24h  -0.99238
# 2       Bitcoin   quote.USD.percent_change_7d   8.28674
# 3       Bitcoin  quote.USD.percent_change_30d  48.62169
# 4       Bitcoin  quote.USD.percent_change_60d  61.43149
# 5       Bitcoin  quote.USD.percent_change_90d  70.33648
# 6      Ethereum   quote.USD.percent_change_1h  -0.42202
# 7      Ethereum  quote.USD.percent_change_24h  -1.25543
# 8      Ethereum   quote.USD.percent_change_7d   6.24050
# 9      Ethereum  quote.USD.percent_change_30d  58.42147
# 10     Ethereum  quote.USD.percent_change_60d  49.64697
# 11     Ethereum  quote.USD.percent_change_90d  79.05833
# 12  Tether USDt   quote.USD.percent_change_1h  -0.00252
# 13  Tether USDt  quote.USD.percent_change_24h  -0.08647
# 14  Tether USDt   quote.USD.percent_change_7d  -0.01904
# 15  Tether USDt  quote.USD.percent_change_30d  -0.03445
# ...

# %%
#df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_1h'],['1h'])
#df7

df7['percent_change'] = df7['percent_change'].replace(['quote.USD.percent_change_24h','quote.USD.percent_change_7d','quote.USD.percent_change_30d','quote.USD.percent_change_60d','quote.USD.percent_change_90d'],['24h','7d','30d','60d','90d'])
df7
# Out:
#            name percent_change    values
# 0       Bitcoin             1h  -0.38674
# 1       Bitcoin            24h  -0.99238
# 2       Bitcoin             7d   8.28674
# 3       Bitcoin            30d  48.62169
# 4       Bitcoin            60d  61.43149
# 5       Bitcoin            90d  70.33648
# 6      Ethereum             1h  -0.42202
# 7      Ethereum            24h  -1.25543
# 8      Ethereum             7d   6.24050
# 9      Ethereum            30d  58.42147
# 10     Ethereum            60d  49.64697
# 11     Ethereum            90d  79.05833
# 12  Tether USDt             1h  -0.00252
# 13  Tether USDt            24h  -0.08647
# 14  Tether USDt             7d  -0.01904
# 15  Tether USDt            30d  -0.03445
# 16  Tether USDt            60d   0.04027
# 17  Tether USDt            90d   0.04843
# 18          BNB             1h   0.09567
# 19          BNB            24h   5.05390
# 20          BNB             7d  31.47989
# 21          BNB            30d  69.05375
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.catplot(x = 'percent_change', y='values', hue='name', data=df7, kind='point')

# %%
# Now to do something much simpler
# we are going to create a dataframe with the columns we want

df8 = df[['name','quote.USD.price','timestamp']]
df8 = df8.query("name == 'Bitcoin'")
df8
# Out:
#       name  quote.USD.price                  timestamp
# 0  Bitcoin      71832.38982 2024-03-12 15:48:57.467632
# 0  Bitcoin      71832.38982 2024-03-12 15:49:08.472061
# 0  Bitcoin      71832.38982 2024-03-12 15:49:19.148629
# 0  Bitcoin      71832.38982 2024-03-12 15:49:29.834636
# 0  Bitcoin      71847.86819 2024-03-12 15:49:40.530092
# 0  Bitcoin      71847.86819 2024-03-12 15:49:51.157639
# 0  Bitcoin      71847.86819 2024-03-12 15:50:04.812629
# 0  Bitcoin      71847.86819 2024-03-12 15:50:15.449497
# 0  Bitcoin      71847.86819 2024-03-12 15:50:26.075646
# 0  Bitcoin      71847.86819 2024-03-12 15:50:36.871643
# 0  Bitcoin      71827.94467 2024-03-12 15:56:47.988636
# 0  Bitcoin      71751.52385 2024-03-12 15:57:48.669666
# 0  Bitcoin      71700.63187 2024-03-12 15:58:49.323635
# 0  Bitcoin      71700.63187 2024-03-12 15:59:50.010651
# 0  Bitcoin      71709.47509 2024-03-12 16:00:50.773643
# 0  Bitcoin      71801.90991 2024-03-12 16:01:51.374634
# ...

# %%
sns.set_theme(style="darkgrid")

sns.lineplot(x='timestamp', y='quote.USD.price', data = df8)
# Out:
# E:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# E:\anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='timestamp', ylabel='quote.USD.price'>
